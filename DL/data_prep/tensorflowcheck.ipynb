# %%
print("Hello")
# Out:
# Hello

# %%
import sys
print(sys.executable)

import numpy as np, tensorflow as tf
print("NumPy:", np.__version__)
print("TensorFlow:", tf.__version__)
# Out:
# c:\Users\sanja_szc7g1i\anaconda3\envs\pd310\python.exe
# NumPy: 1.26.4
# TensorFlow: 2.10.1

# %%
import tensorflow as tf
tf.config.list_physical_devices('GPU')

tf.test.is_gpu_available()
# Out:
# WARNING:tensorflow:From C:\Users\sanja_szc7g1i\AppData\Local\Temp\ipykernel_27388\3772949640.py:4: is_gpu_available (from tensorflow.python.framework.test_util) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.config.list_physical_devices('GPU')` instead.
# True

# %%
import tensorflow as tf

print("Num GPUs Available:", len(tf.config.list_physical_devices('GPU')))
print("GPU Devices:", tf.config.list_physical_devices('GPU'))

# Optional: show detailed info
gpus = tf.config.list_physical_devices('GPU')
for gpu in gpus:
    print(gpu)
# Out:
# Num GPUs Available: 1
# GPU Devices: [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]
# PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')

# %%
import tensorflow as tf
print(tf.config.list_physical_devices('GPU'))
# Out:
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %%
import tensorflow as tf

print("Num GPUs Available:", len(tf.config.list_physical_devices('GPU')))
print("GPU Devices:", tf.config.list_physical_devices('GPU'))

# Optional: show detailed info
gpus = tf.config.list_physical_devices('GPU')
for gpu in gpus:
    print(gpu)
# Out:
# Num GPUs Available: 1
# GPU Devices: [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]
# PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')
